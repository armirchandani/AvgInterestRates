# %% [markdown]
# <a href="https://colab.research.google.com/github/armirchandani/pandas/blob/main/kwk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Data Collection and Processing

# %%
# loading the csv data to a Pandas DataFrame
df = pd.read_csv('/content/hom_01.csv')

# %%
df
# Out:
#       activity_year  derived_race_or_ethnicity applicant_age derived_sex  \
# 0              2019  Black or African American           >74      Female
# 1              2024                      Asian           >74      Female
# 2              2023                      Asian           >74       Joint
# 3              2019                      Asian           >74      Female
# 4              2019         Hispanic or Latino           >74      Female
# ...             ...                        ...           ...         ...
# 2347           2024         Hispanic or Latino         45-54        Male
# 2348           2024         Hispanic or Latino         55-64        Male
# 2349           2024                      Asian           >74        Male
# 2350           2024                      Asian         65-74        Male
# 2351           2023                      Asian           >74        Male
#
#                                   action_taken_text  average_interest_rate  \
# ...

# %%
# Removing columns we don't need
df = df.drop(columns=["median_interest_rate","median_loan_amount","median_property_value","average_loan_amount","average_property_value"])
df
# Out:
#       activity_year  derived_race_or_ethnicity applicant_age derived_sex  \
# 0              2019  Black or African American           >74      Female
# 1              2024                      Asian           >74      Female
# 2              2023                      Asian           >74       Joint
# 3              2019                      Asian           >74      Female
# 4              2019         Hispanic or Latino           >74      Female
# ...             ...                        ...           ...         ...
# 2347           2024         Hispanic or Latino         45-54        Male
# 2348           2024         Hispanic or Latino         55-64        Male
# 2349           2024                      Asian           >74        Male
# 2350           2024                      Asian         65-74        Male
# 2351           2023                      Asian           >74        Male
#
#                                   action_taken_text  average_interest_rate
# ...

# %%
#print first 5 rows
df.head()
# Out:
#    activity_year  derived_race_or_ethnicity applicant_age derived_sex  \
# 0           2019  Black or African American           >74      Female
# 1           2024                      Asian           >74      Female
# 2           2023                      Asian           >74       Joint
# 3           2019                      Asian           >74      Female
# 4           2019         Hispanic or Latino           >74      Female
#
#                                action_taken_text  average_interest_rate
# 0  Preapproval request approved but not accepted                    NaN
# 1  Preapproval request approved but not accepted                    NaN
# 2  Preapproval request approved but not accepted                    NaN
# 3  Preapproval request approved but not accepted                    NaN
# 4  Preapproval request approved but not accepted                    NaN

# %%
#Removing rows we don't need
df = df[~df['derived_race_or_ethnicity'].isin(['Asian', 'Hispanic or Latino', 'White'])]
df
# Out:
#       activity_year  derived_race_or_ethnicity applicant_age derived_sex  \
# 0              2019  Black or African American           >74      Female
# 17             2020  Black or African American           <25       Joint
# 32             2021  Black or African American           >74        Male
# 47             2021  Black or African American         65-74        Male
# 61             2021  Black or African American           >74       Joint
# ...             ...                        ...           ...         ...
# 2288           2024  Black or African American         45-54        Male
# 2293           2023  Black or African American           >74      Female
# 2306           2023  Black or African American         45-54        Male
# 2325           2020  Black or African American           >74        Male
# 2336           2019  Black or African American           <25       Joint
#
#                                   action_taken_text  average_interest_rate
# ...

# %%
#Checking for null data
df.isnull().sum()
# Out:
# activity_year                0
# derived_race_or_ethnicity    0
# applicant_age                0
# derived_sex                  0
# action_taken_text            0
# average_interest_rate        1
# dtype: int64

# %%
df = df.fillna('')

# %%
df.isnull().sum()
# Out:
# activity_year                0
# derived_race_or_ethnicity    0
# applicant_age                0
# derived_sex                  0
# action_taken_text            0
# average_interest_rate        0
# dtype: int64

# %%
df
# Out:
#       activity_year  derived_race_or_ethnicity applicant_age derived_sex  \
# 0              2019  Black or African American           >74      Female
# 17             2020  Black or African American           <25       Joint
# 32             2021  Black or African American           >74        Male
# 47             2021  Black or African American         65-74        Male
# 61             2021  Black or African American           >74       Joint
# ...             ...                        ...           ...         ...
# 2288           2024  Black or African American         45-54        Male
# 2293           2023  Black or African American           >74      Female
# 2306           2023  Black or African American         45-54        Male
# 2325           2020  Black or African American           >74        Male
# 2336           2019  Black or African American           <25       Joint
#
#                                   action_taken_text average_interest_rate
# ...

# %%
#Removing "Joint" loan approvals

# %%
# Out:
#       activity_year  derived_race_or_ethnicity applicant_age derived_sex  \
# 0              2019  Black or African American           >74      Female
# 17             2020  Black or African American           <25       Joint
# 32             2021  Black or African American           >74        Male
# 47             2021  Black or African American         65-74        Male
# 61             2021  Black or African American           >74       Joint
# ...             ...                        ...           ...         ...
# 2288           2024  Black or African American         45-54        Male
# 2293           2023  Black or African American           >74      Female
# 2306           2023  Black or African American         45-54        Male
# 2325           2020  Black or African American           >74        Male
# 2336           2019  Black or African American           <25       Joint
#
#                                   action_taken_text average_interest_rate
# ...
